# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Supervised Learning

# %% [markdown]
# - Data has some label or output value you expect to be able to predict
# - Regression, Classification

# %% [markdown]
# #### Unsupervised Learning

# %% [markdown]
# - Data has no labels or expected outputs
# - Clustering, Visualization, Dimensionality Reduction, Association Rule Learning

# %% [markdown]
# #### Reinforcement Learning

# %% [markdown]
# - Give model a reward based on how close it gets to some goal
# - Teach robot to walk on unexpected terrain

# %% [markdown]
# #### Clustering

# %% [markdown]
# - Group data into some unknown amount of groups -> if you know groups, use classification

# %% [markdown]
# #### Online vs Offline Learning

# %% [markdown]
# - Online learning trains as new data comes in, allowing the model to learn incrementally
# - Offline is trained all at once

# %% [markdown]
# #### Out of Core Learning

# %% [markdown]
# Out-of-core algorithms can handle vast quantities of data that cannot fit in a computer's main memory. An out-of-core learning algorithm chops the data into mini-batches and uses online learning techniques to learn from these mini-batches.

# %% [markdown]
# #### Instance Based Learning

# %% [markdown]
# An instance-based learning system learns the training data by heart; then, when given a new instance, it uses a similarity measure to find the most similar learned instances and uses them to make predictions.

# %% [markdown]
# #### Parameters vs Hyperparameters

# %% [markdown]
# - A model has one or more model parameters that determine what it will predict given a new instance (e.g., the slope of a linear model). A learning algorithm tries to find optimal values for these parameters such that the model generalizes well to new instances.
# - A hyperparameter is a parameter of the learning algorithm itself, not of the model (e.g., the amount of regularization to apply).

# %% [markdown]
# #### Model Based Algorithms

# %% [markdown]
# Model-based learning algorithms search for an optimal value for the model parameters such that the model will generalize well to new instances. We usually train such systems by minimizing a cost function that measures how bad the system is at making predictions on the training data, plus a penalty for model complexity if the model is regularized. To make predictions, we feed the new instance's features into the model's prediction function, using the parameter values found by the learning algorithm

# %% [markdown]
# #### Overfitting

# %% [markdown]
# - A model learns the training data, but doesn't generalize
# - Solutions: Get more data, simplify the model, reduce noise in the data

# %% [markdown]
# #### Train, Test, Validate

# %% [markdown]
# - Split data into train and test sets. Add a validation set if you are comparing different models.
# - Test the models accuracy with the test set. Compare models with the validation set.
